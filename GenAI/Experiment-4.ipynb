# %%
import gensim.downloader as api
from transformers import pipeline
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/mckb/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
wv = api.load("glove-wiki-gigaword-50")
gen = pipeline("text-generation", model="gpt2")
# Out:
# Device set to use cpu

# %%
p = "who is king"
print("Original:", p)
# Out:
# Original: who is king

# %%
try:
    p2 = p.replace("king", wv.most_similar("king")[0][0])
except:
    p2 = p
print("Enriched:", p2)
# Generate
o1 = gen(p)[0]['generated_text']
o2 = gen(p2)[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Enriched: who is prince
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print("\nOriginal:\n", o1)
print("\nEnriched:\n", o2)
print("\nLength:", len(o1), len(o2))
print("Detail:", o1.count("."), o2.count("."))
# Out:
# Original:
#  who is king and queen), who can make the best of most of his life; and what the Lord himself has made for us, what we have not made for ourselves.
#
# 7. But if we are a man, and we are an angel, if we are a man and we are an angel, if we are a man and I am an angel, we are a man and we are an angel, and not the things which I say come from God; but we are the things which I say come from God, that I may give unto you everything which I have given you to go out of, to make for you, so that you may understand that I am making for you, and that I am making for you, as I have made for you, even as I have made for you, to make for yourself a house of life and to make for you a house of righteousness, so that you may be able to obey the commandments which the Lord hath given you to go out of, and to make for you, so that you may be able to obey the commands which the Lord hath given you to go out of, and to make for you, as I have given you to go out of, and to make for you, as I have given you to go
#
# Enriched:
#  who is prince of Aqaba, whom God has bestowed upon us on earth, and who is in the midst of the whole world, and who is God's servant and guide and protector, and who is the one and only one, and who is the only one whom God has bestowed upon us on earth, and who is the one and only one, and who is the one and only one whom God has bestowed upon us on earth, and who is the one and only one, and who is the one and only one, and who is the one and only one, and who is the one and only one, and who is the one and only one, and who is the one and only one, and who is the one and only one, and who is the one and only one, and who is the one and only one, and who is the one and only one, and who is the one and only one, and who is the one and only one, and who is the one and only one, and who is the one and only one, and who is the one and only one, and who is the one and only one, and who is the one and only one, and who is the one and only one, and who is the one and only one
#
# Length: 1007 985
# Detail: 2 0
