# %%
#!pip install transformers gensim nltk
import gensim.downloader as api
from transformers import pipeline
import nltk
nltk.download('punkt')
wv = api.load("glove-wiki-gigaword-100")
gen = pipeline("text-generation", model="gpt2")
p = "who is king"
print("Original:", p)
# Replace "king"
try:
    p2 = p.replace("king", wv.most_similar("king")[0][0])
except:
    p2 = p
print("Enriched:", p2)
# Generate
o1 = gen(p, max_length=100)[0]['generated_text']
o2 = gen(p2, max_length=100)[0]['generated_text']
print("\nOriginal:\n", o1)
print("\nEnriched:\n", o2)
print("\nLength:", len(o1), len(o2))
print("Detail:", o1.count("."), o2.count("."))
# Out:
# [nltk_data] Downloading package punkt to /home/mckb/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 16
#      12 # Load models manually (avoids pipeline torch bug)
#      13 wv = api.load("glove-wiki-gigaword-100")
#      14
#      15 tokenizer = AutoTokenizer.from_pretrained("gpt2")
# ---> 16 model = AutoModelForCausalLM.from_pretrained("gpt2")
#      17
#      18 prompt = "Who is king."
#      19
#
# File ~/Git/College/GenAI/.venv/lib/python3.14/site-packages/transformers/utils/import_utils.py:2040, in DummyObject.__getattribute__(cls, key)
#    2038 if (key.startswith("_") and key != "_from_config") or key == "is_dummy" or key == "mro" or key == "call":
#    2039     return super().__getattribute__(key)
# -> 2040 requires_backends(cls, cls._backends)
#
# File ~/Git/College/GenAI/.venv/lib/python3.14/site-packages/transformers/utils/import_utils.py:2026, in requires_backends(obj, backends)
#    2023         failed.append(msg.format(name))
#    2025 if failed:
# -> 2026     raise ImportError("".join(failed))
#
# ImportError:
# AutoModelForCausalLM requires the PyTorch library but it was not found in your environment. Check out the instructions on the
# installation page: https://pytorch.org/get-started/locally/ and follow the ones that match your environment.
# Please note that you may need to restart your runtime after installation.
