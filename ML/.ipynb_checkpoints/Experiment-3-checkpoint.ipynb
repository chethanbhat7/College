# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Iris.csv")
x, y = "SepalLengthCm", "SepalWidthCm"

plt.figure(figsize=(8,6))
plt.scatter(df[x], df[y])
plt.title(f"Scatter Plot of {x} vs {y}")
plt.xlabel(x)
plt.ylabel(y)
plt.grid(True)
plt.show()

print(f"Pearson Correlation Coefficient ({x} vs {y}): ",df[x].corr(df[y]))

cov_matrix = df[[x, y]].cov()
print("\nCovariance Matrix:")
print(cov_matrix)

correlation_matrix = df[[x, y]].corr()
print("\nCorrelation Matrix:")
print(correlation_matrix)

plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, vmin=-1, vmax=1, annot=True)
plt.title("Correlation Matrix Heatmap")
plt.show()
# Out:
# Pearson Correlation Coefficient (SepalLengthCm vs SepalWidthCm):  -0.10936924995064937
#
# Covariance Matrix:
#                SepalLengthCm  SepalWidthCm
# SepalLengthCm       0.685694     -0.039268
# SepalWidthCm       -0.039268      0.188004
#
# Correlation Matrix:
#                SepalLengthCm  SepalWidthCm
# SepalLengthCm       1.000000     -0.109369
# SepalWidthCm       -0.109369      1.000000

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Iris.csv')

# %%
x='SepalLengthCm'
y='SepalWidthCm'

# %%
plt.scatter(df[x],df[y])

# %%
print('pearson corr',df[x].corr(df[y]))
# Out:
# pearson corr -0.10936924995064937

# %%
print("cov matrix")
df[[x,y]].cov()
# Out:
# cov matrix
#                SepalLengthCm  SepalWidthCm
# SepalLengthCm       0.685694     -0.039268
# SepalWidthCm       -0.039268      0.188004

# %%
print('cor matrix')
corr=df[[x,y]].corr()
print(corr)
# Out:
# cor matrix
#                SepalLengthCm  SepalWidthCm
# SepalLengthCm       1.000000     -0.109369
# SepalWidthCm       -0.109369      1.000000

# %%
sns.heatmap(corr,vmin=-1,vmax=+1,annot=True)
# Out:
# <Axes: >
