# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load data
df = pd.read_csv("BostonHousing.csv")

# Select columns
X = df[['RM']]
y = df['MEDV']

# Train
model = LinearRegression().fit(X, y)

# Plot
plt.scatter(X, y, alpha=0.5, label='Actual')
plt.plot(X, model.predict(X), color='red', label='Trend')
plt.title("Linear Regression: RM vs MEDV")
plt.legend()

# Accuracy
print("R² Score:", model.score(X, y))
# Out:
# R² Score: 0.48352545599133423

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("auto-mpg.csv", na_values='?').dropna()

X, y = df['horsepower'], df['mpg']

model = np.poly1d(np.polyfit(X, y, 2))
xp = np.linspace(X.min(), X.max())

plt.scatter(X, y, alpha=0.5)
plt.plot(xp, model(xp), color='red')
plt.title("Polynomial Regression: Horsepower vs MPG")
plt.show()

print(f"Prediction for 100HP: {model(100):.2f}")
# Out:
# Prediction for 100HP: 22.59

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('BostonHousing.csv')

# %%
X=df[['RM']]
y=df['MEDV']

# %%
model=LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
plt.scatter(X,y)
plt.plot(X,model.predict(X),color='red')
model.predict([[5]])
# Out:
# /home/mckb/Git/College/ML/.venv/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([10.83992413])

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('auto-mpg.csv',na_values='?').dropna()

# %%
X=df['horsepower']
y=df['mpg']

# %%
model=np.poly1d(np.polyfit(X,y,2))

# %%
plt.scatter(X,y)
xp=np.linspace(X.max(),X.min())
plt.plot(xp,model(xp),color='red')

# %%
model(100)
# Out:
# np.float64(22.58649771511682)
