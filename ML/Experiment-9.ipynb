# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

df = pd.read_csv("breast-cancer.csv")

X = StandardScaler().fit_transform(df.drop(columns=['id', 'diagnosis', 'Unnamed: 32'], errors='ignore'))
y = df['diagnosis']

labels = KMeans(2).fit_predict(X)


X = PCA(2).fit_transform(X)

plt.scatter(X[labels == 0, 0], X[labels == 0, 1], label='cluster0')
plt.scatter(X[labels == 1, 0], X[labels == 1, 1], label='cluster1')

plt.scatter(X[y == 'M', 0], X[y == 'M', 1], label='Actual Malignant', marker='x')
plt.scatter(X[y == 'B', 0], X[y == 'B', 1], label='Actual Benign', marker='+')

plt.title("K-Means Clustering on Breast Cancer Dataset")
plt.legend()
plt.show()
