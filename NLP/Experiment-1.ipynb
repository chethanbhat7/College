# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
nltk.download('punkt_tab')
nltk.download('stopwords')

def preprocess(text):
    words = nltk.word_tokenize(text)
    print("Tokenized:", words)

    words = [w for w in words if w.isalnum()]
    print("Filtered:", words)

    words=[w for w in words if w.isalpha()]
    print("validated:",words)

    words = [w for w in words if w not in stopwords.words()]
    print("No Stopwords:", words)

    stemmer = PorterStemmer()
    words = [stemmer.stem(w) for w in words]
    print("Stemmed:", words)

    return words

text = "Natural Language Processing (NLP) is a fascinating field of Artificial Intelligence!"
preprocess(text)
# Out:
# Tokenized: ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'fascinating', 'field', 'of', 'Artificial', 'Intelligence', '!']
# Filtered: ['Natural', 'Language', 'Processing', 'NLP', 'is', 'a', 'fascinating', 'field', 'of', 'Artificial', 'Intelligence']
# validated: ['Natural', 'Language', 'Processing', 'NLP', 'is', 'a', 'fascinating', 'field', 'of', 'Artificial', 'Intelligence']
# No Stopwords: ['Natural', 'Language', 'Processing', 'NLP', 'fascinating', 'field', 'Artificial', 'Intelligence']
# Stemmed: ['natur', 'languag', 'process', 'nlp', 'fascin', 'field', 'artifici', 'intellig']
# [nltk_data] Downloading package punkt_tab to /home/mckb/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/mckb/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['natur',
#  'languag',
#  'process',
#  'nlp',
#  'fascin',
#  'field',
#  'artifici',
#  'intellig']

# %%
from langdetect import detect
text="notebook is on the table"
print(detect(text))
# Out:
# en
