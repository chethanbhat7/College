# %%
import nltk
from nltk.corpus import wordnet as wn

nltk.download('wordnet')

w="active"
syn={l.name() for s in wn.synsets(w) for l in s.lemmas()}
ant={l.antonyms()[0].name() for s in wn.synsets(w) for l in s.lemmas() if l.antonyms()}

print(w, "\nSyn:", syn, "\nAnt:", ant)
# Out:
# active
# Syn: {'dynamic', 'active_agent', 'participating', 'alive', 'fighting', 'active_voice', 'combat-ready', 'active'}
# Ant: {'passive', 'quiet', 'stative', 'inactive', 'extinct', 'dormant', 'passive_voice'}
# [nltk_data] Downloading package wordnet to /home/mckb/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
